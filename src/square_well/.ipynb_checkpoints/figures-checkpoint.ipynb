# %%
import matplotlib.pyplot as plt

import sys
sys.path.append('../')
from utils import get_train_results, add_subplot, set_size

# %%
fig, axs = plt.subplots(2, 2, figsize=(6, 5))

model_name = 'cnn'

# k=0.01
y_test, predictions, history, r = get_train_results(model_name, "k0.01")
print('k=0.1: pearson coefs=', r)

xmax = 280
xmin = -xmax/100
add_subplot(axs, 0, y_test, predictions, history, epoch_xlim=(xmin, xmax), str_labels=('(a) k=0.01', '(b)'), nticks=4)

# k=0.1
y_test, predictions, history, r = get_train_results(model_name, "k0.1")
print('k=0.5: pearson coefs=', r)

xmax = 110
xmin = -xmax/100
add_subplot(axs, 1, y_test, predictions, history, epoch_xlim=(xmin, xmax), str_labels=('(c) k=0.1', '(d)'), nticks=4)

plt.tight_layout()
plt.savefig('output/'+model_name+'/sqw_delta0_scatter.pdf', format='pdf')
plt.show()
# Out:
# k=0.1: pearson coefs= 0.999904364806394
# k=0.5: pearson coefs= 0.9999639127783438
# ../utils/__init__.py:70: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   spine.set_smart_bounds(True)
# ../utils/__init__.py:70: MatplotlibDeprecationWarning:
# The set_smart_bounds function was deprecated in Matplotlib 3.2 and will be removed two minor releases later.
#   spine.set_smart_bounds(True)
